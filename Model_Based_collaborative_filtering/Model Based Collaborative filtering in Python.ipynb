# %%
from IPython.display import Image

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Model Based Collaborative filtering in Python.ipynb',
#  'model_based_CF-1.PNG',
#  'model_based_CF-2.PNG',
#  'model_based_CF-3.PNG']

# %%
Image('model_based_CF-1.PNG',)

# %%
Image('model_based_CF-2.PNG',)

# %%
Image('model_based_CF-3.PNG',)
